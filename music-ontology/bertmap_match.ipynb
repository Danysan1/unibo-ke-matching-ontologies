# %%
# !pip3 install torch torchvision torchaudio deeponto
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.0.2+cu118)
# Requirement already satisfied: deeponto in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: JPype1==1.3.0 in /usr/local/lib/python3.10/dist-packages (from deeponto) (1.3.0)
# Requirement already satisfied: yacs in /usr/local/lib/python3.10/dist-packages (from deeponto) (0.1.8)
# Requirement already satisfied: anytree==2.8.0 in /usr/local/lib/python3.10/dist-packages (from deeponto) (2.8.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from deeponto) (8.1.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from deeponto) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from deeponto) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from deeponto) (1.2.2)
# Requirement already satisfied: openprompt==1.0.0 in /usr/local/lib/python3.10/dist-packages (from deeponto) (1.0.0)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (from deeponto) (4.30.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from deeponto) (2.13.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from deeponto) (3.5.4)
# Requirement already satisfied: pprintpp in /usr/local/lib/python3.10/dist-packages (from deeponto) (0.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from deeponto) (4.9.3)
# Requirement already satisfied: textdistance in /usr/local/lib/python3.10/dist-packages (from deeponto) (4.5.0)
# Requirement already satisfied: ipywidgets==7.7.1 in /usr/local/lib/python3.10/dist-packages (from deeponto) (7.7.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from deeponto) (5.5.6)
# Requirement already satisfied: enlighten in /usr/local/lib/python3.10/dist-packages (from deeponto) (1.11.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from anytree==2.8.0->deeponto) (1.16.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1->deeponto) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1->deeponto) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1->deeponto) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1->deeponto) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==7.7.1->deeponto) (3.0.8)
# Requirement already satisfied: sentencepiece==0.1.96 in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (0.1.96)
# Requirement already satisfied: tqdm>=4.62.2 in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (4.65.0)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (2.6.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (3.8.1)
# Requirement already satisfied: rouge==1.0.0 in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (1.0.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (9.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from openprompt==1.0.0->deeponto) (1.10.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->deeponto) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->deeponto) (6.3.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->deeponto) (6.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: blessed>=1.17.7 in /usr/local/lib/python3.10/dist-packages (from enlighten->deeponto) (1.20.0)
# Requirement already satisfied: prefixed>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from enlighten->deeponto) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deeponto) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deeponto) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->deeponto) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->deeponto) (3.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (1.10.11)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->deeponto) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]->deeponto) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]->deeponto) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]->deeponto) (0.3.1)
# Requirement already satisfied: accelerate>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]->deeponto) (0.21.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.2->transformers[torch]->deeponto) (5.9.5)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.7->enlighten->deeponto) (0.2.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->deeponto) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->deeponto) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->deeponto) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->deeponto) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->deeponto) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->deeponto) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (4.8.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->deeponto) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->deeponto) (0.1.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (6.4.8)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->deeponto) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->deeponto) (23.2.1)
# Requirement already satisfied: protobuf>=4.22.3 in /usr/local/lib/python3.10/dist-packages (from tensorboardX->openprompt==1.0.0->deeponto) (4.23.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->deeponto) (3.8.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (21.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (5.9.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1->deeponto) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (21.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->deeponto) (2.21)

# %%
from deeponto.onto import Ontology
from deeponto.align.bertmap import BERTMapPipeline, DEFAULT_CONFIG_FILE
# Out:
# Please enter the maximum memory located to JVM [8g]:
#
# 8g maximum memory allocated to JVM.
# JVM started successfully.

# %%
config_file = "bertmap.yaml"
#config_file = DEFAULT_CONFIG_FILE
src_onto_file = "core.owl"
tgt_onto_file = "mo.owl"

# %%
config = BERTMapPipeline.load_bertmap_config(config_file)
#BERTMapPipeline.save_bertmap_config(config, "bertmap.yaml")

# %%
src_onto = Ontology(src_onto_file)

# %%
tgt_onto = Ontology(tgt_onto_file)

# %%
bertmap = BERTMapPipeline(src_onto, tgt_onto, config)
# Out:
# [Time: 00:01:11] - [PID: 4923] - [Model: bertmap]
# Load the following configurations:
# {
#     "model": "bertmap",
#     "output_path": "/content",
#     "annotation_property_iris": [
#         "http://www.w3.org/2000/01/rdf-schema#label",
#         "http://www.geneontology.org/formats/oboInOwl#hasSynonym",
#         "http://www.geneontology.org/formats/oboInOwl#hasExactSynonym",
#         "http://www.w3.org/2004/02/skos/core#exactMatch",
#         "http://www.ebi.ac.uk/efo/alternative_term",
#         "http://www.orpha.net/ORDO/Orphanet_#symbol",
#         "http://purl.org/sig/ont/fma/synonym",
#         "http://www.w3.org/2004/02/skos/core#prefLabel",
#         "http://www.w3.org/2004/02/skos/core#altLabel",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P108",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P90"
#     ],
#     "known_mappings": "known_mappings.tsv",
#     "auxiliary_ontos": [],
#     "bert": {
#         "pretrained_path": "bert-base-uncased",
#         "max_length_for_input": 128,
#         "num_epochs_for_training": 3.0,
#         "batch_size_for_training": 8,
#         "batch_size_for_prediction": 128,
#         "resume_training": null
#     },
#     "global_matching": {
#         "enabled": true,
#         "num_raw_candidates": 200,
#         "num_best_predictions": 10,
#         "mapping_extension_threshold": 0.8,
#         "mapping_filtered_threshold": 0.9
#     }
# }
# [Time: 00:00:23] - [PID: 4923] - [Model: bertmap]
# Load the following configurations:
# {
#     "model": "bertmap",
#     "output_path": "/content",
#     "annotation_property_iris": [
#         "http://www.w3.org/2000/01/rdf-schema#label",
#         "http://www.geneontology.org/formats/oboInOwl#hasSynonym",
#         "http://www.geneontology.org/formats/oboInOwl#hasExactSynonym",
#         "http://www.w3.org/2004/02/skos/core#exactMatch",
#         "http://www.ebi.ac.uk/efo/alternative_term",
#         "http://www.orpha.net/ORDO/Orphanet_#symbol",
#         "http://purl.org/sig/ont/fma/synonym",
#         "http://www.w3.org/2004/02/skos/core#prefLabel",
#         "http://www.w3.org/2004/02/skos/core#altLabel",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P108",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P90"
#     ],
#     "known_mappings": "known_mappings.tsv",
#     "auxiliary_ontos": [],
#     "bert": {
#         "pretrained_path": "bert-base-uncased",
#         "max_length_for_input": 128,
#         "num_epochs_for_training": 3.0,
#         "batch_size_for_training": 8,
#         "batch_size_for_prediction": 128,
#         "resume_training": null
#     },
#     "global_matching": {
#         "enabled": true,
#         "num_raw_candidates": 200,
#         "num_best_predictions": 10,
#         "mapping_extension_threshold": 0.8,
#         "mapping_filtered_threshold": 0.9
#     }
# }
# [Time: 00:00:00] - [PID: 4923] - [Model: bertmap]
# Load the following configurations:
# {
#     "model": "bertmap",
#     "output_path": "/content",
#     "annotation_property_iris": [
#         "http://www.w3.org/2000/01/rdf-schema#label",
#         "http://www.geneontology.org/formats/oboInOwl#hasSynonym",
#         "http://www.geneontology.org/formats/oboInOwl#hasExactSynonym",
#         "http://www.w3.org/2004/02/skos/core#exactMatch",
#         "http://www.ebi.ac.uk/efo/alternative_term",
#         "http://www.orpha.net/ORDO/Orphanet_#symbol",
#         "http://purl.org/sig/ont/fma/synonym",
#         "http://www.w3.org/2004/02/skos/core#prefLabel",
#         "http://www.w3.org/2004/02/skos/core#altLabel",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P108",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P90"
#     ],
#     "known_mappings": "known_mappings.tsv",
#     "auxiliary_ontos": [],
#     "bert": {
#         "pretrained_path": "bert-base-uncased",
#         "max_length_for_input": 128,
#         "num_epochs_for_training": 3.0,
#         "batch_size_for_training": 8,
#         "batch_size_for_prediction": 128,
#         "resume_training": null
#     },
#     "global_matching": {
#         "enabled": true,
#         "num_raw_candidates": 200,
#         "num_best_predictions": 10,
#         "mapping_extension_threshold": 0.8,
#         "mapping_filtered_threshold": 0.9
#     }
# }
# INFO:bertmap:Load the following configurations:
# {
#     "model": "bertmap",
#     "output_path": "/content",
#     "annotation_property_iris": [
#         "http://www.w3.org/2000/01/rdf-schema#label",
#         "http://www.geneontology.org/formats/oboInOwl#hasSynonym",
#         "http://www.geneontology.org/formats/oboInOwl#hasExactSynonym",
#         "http://www.w3.org/2004/02/skos/core#exactMatch",
#         "http://www.ebi.ac.uk/efo/alternative_term",
#         "http://www.orpha.net/ORDO/Orphanet_#symbol",
#         "http://purl.org/sig/ont/fma/synonym",
#         "http://www.w3.org/2004/02/skos/core#prefLabel",
#         "http://www.w3.org/2004/02/skos/core#altLabel",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P108",
#         "http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P90"
#     ],
#     "known_mappings": "known_mappings.tsv",
#     "auxiliary_ontos": [],
#     "bert": {
#         "pretrained_path": "bert-base-uncased",
#         "max_length_for_input": 128,
#         "num_epochs_for_training": 3.0,
#         "batch_size_for_training": 8,
#         "batch_size_for_prediction": 128,
#         "resume_training": null
#     },
#     "global_matching": {
#         "enabled": true,
#         "num_raw_candidates": 200,
#         "num_best_predictions": 10,
#         "mapping_extension_threshold": 0.8,
#         "mapping_filtered_threshold": 0.9
#     }
# }
# [Time: 00:01:11] - [PID: 4923] - [Model: bertmap]
# Save the configuration file at /content/bertmap/config.yaml.
# [Time: 00:00:23] - [PID: 4923] - [Model: bertmap]
# Save the configuration file at /content/bertmap/config.yaml.
# [Time: 00:00:00] - [PID: 4923] - [Model: bertmap]
# Save the configuration file at /content/bertmap/config.yaml.
# INFO:bertmap:Save the configuration file at /content/bertmap/config.yaml.
# [Time: 00:01:12] - [PID: 4923] - [Model: bertmap]
# Construct new text semantics corpora and save at /content/bertmap/data/text-semantics.corpora.json.
# [Time: 00:00:23] - [PID: 4923] - [Model: bertmap]
# Construct new text semantics corpora and save at /content/bertmap/data/text-semantics.corpora.json.
# [Time: 00:00:00] - [PID: 4923] - [Model: bertmap]
# Construct new text semantics corpora and save at /content/bertmap/data/text-semantics.corpora.json.
# INFO:bertmap:Construct new text semantics corpora and save at /content/bertmap/data/text-semantics.corpora.json.
# [Time: 00:01:12] - [PID: 4923] - [Model: bertmap]
# {
#     "TextSemanticsCorpora": {
#         "num_synonyms": 132,
#         "num_nonsynonyms": 526,
#         "intra_src_onto_corpus": {
#             "num_synonyms": 51,
#             "num_nonsynonyms": 204,
#             "num_soft_nonsynonyms": 136,
#             "num_hard_nonsynonyms": 68,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             }
#         },
#         "intra_tgt_onto_corpus": {
#             "num_synonyms": 82,
#             "num_nonsynonyms": 328,
#             "num_soft_nonsynonyms": 166,
#             "num_hard_nonsynonyms": 162,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "cross_onto_corpus": {
#             "num_synonyms": 0,
#             "num_nonsynonyms": 0,
#             "num_mappings": 12,
#             "src_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             },
#             "tgt_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "auxiliary_onto_corpora": []
#     }
# }
# [Time: 00:00:23] - [PID: 4923] - [Model: bertmap]
# {
#     "TextSemanticsCorpora": {
#         "num_synonyms": 132,
#         "num_nonsynonyms": 526,
#         "intra_src_onto_corpus": {
#             "num_synonyms": 51,
#             "num_nonsynonyms": 204,
#             "num_soft_nonsynonyms": 136,
#             "num_hard_nonsynonyms": 68,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             }
#         },
#         "intra_tgt_onto_corpus": {
#             "num_synonyms": 82,
#             "num_nonsynonyms": 328,
#             "num_soft_nonsynonyms": 166,
#             "num_hard_nonsynonyms": 162,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "cross_onto_corpus": {
#             "num_synonyms": 0,
#             "num_nonsynonyms": 0,
#             "num_mappings": 12,
#             "src_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             },
#             "tgt_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "auxiliary_onto_corpora": []
#     }
# }
# [Time: 00:00:00] - [PID: 4923] - [Model: bertmap]
# {
#     "TextSemanticsCorpora": {
#         "num_synonyms": 132,
#         "num_nonsynonyms": 526,
#         "intra_src_onto_corpus": {
#             "num_synonyms": 51,
#             "num_nonsynonyms": 204,
#             "num_soft_nonsynonyms": 136,
#             "num_hard_nonsynonyms": 68,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             }
#         },
#         "intra_tgt_onto_corpus": {
#             "num_synonyms": 82,
#             "num_nonsynonyms": 328,
#             "num_soft_nonsynonyms": 166,
#             "num_hard_nonsynonyms": 162,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "cross_onto_corpus": {
#             "num_synonyms": 0,
#             "num_nonsynonyms": 0,
#             "num_mappings": 12,
#             "src_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             },
#             "tgt_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "auxiliary_onto_corpora": []
#     }
# }
# INFO:bertmap:{
#     "TextSemanticsCorpora": {
#         "num_synonyms": 132,
#         "num_nonsynonyms": 526,
#         "intra_src_onto_corpus": {
#             "num_synonyms": 51,
#             "num_nonsynonyms": 204,
#             "num_soft_nonsynonyms": 136,
#             "num_hard_nonsynonyms": 68,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             }
#         },
#         "intra_tgt_onto_corpus": {
#             "num_synonyms": 82,
#             "num_nonsynonyms": 328,
#             "num_soft_nonsynonyms": 166,
#             "num_hard_nonsynonyms": 162,
#             "annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "cross_onto_corpus": {
#             "num_synonyms": 0,
#             "num_nonsynonyms": 0,
#             "num_mappings": 12,
#             "src_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "core.owl",
#                     "num_classes": 49,
#                     "num_object_properties": 75,
#                     "num_data_properties": 13,
#                     "num_annotation_properties": 8
#                 },
#                 "average_number_of_annotations_per_class": 1.0,
#                 "number_of_synonym_groups": 49
#             },
#             "tgt_annotation_thesaurus": {
#                 "ontology": {
#                     "loaded_from": "mo.owl",
#                     "num_classes": 100,
#                     "num_object_properties": 144,
#                     "num_data_properties": 49,
#                     "num_annotation_properties": 83
#                 },
#                 "average_number_of_annotations_per_class": 0.82,
#                 "number_of_synonym_groups": 100
#             }
#         },
#         "auxiliary_onto_corpora": []
#     }
# }
# [Time: 00:01:12] - [PID: 4923] - [Model: bertmap]
# Construct new fine-tuning data and save at /content/bertmap/data/fine-tune.data.json.
# [Time: 00:00:23] - [PID: 4923] - [Model: bertmap]
# Construct new fine-tuning data and save at /content/bertmap/data/fine-tune.data.json.
# [Time: 00:00:00] - [PID: 4923] - [Model: bertmap]
# Construct new fine-tuning data and save at /content/bertmap/data/fine-tune.data.json.
# INFO:bertmap:Construct new fine-tuning data and save at /content/bertmap/data/fine-tune.data.json.
# Loading a BERT model from: bert-base-uncased.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading and preparing dataset generator/default to /root/.cache/huggingface/datasets/generator/default-438e7e7591db5d00/0.0.0...
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset generator downloaded and prepared to /root/.cache/huggingface/datasets/generator/default-438e7e7591db5d00/0.0.0. Subsequent calls will reuse this data.
# Load training data::   0%|          | 0/592 [00:00<?, ? examples/s]
# Downloading and preparing dataset generator/default to /root/.cache/huggingface/datasets/generator/default-88ac5d3b365d7fd5/0.0.0...
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset generator downloaded and prepared to /root/.cache/huggingface/datasets/generator/default-88ac5d3b365d7fd5/0.0.0. Subsequent calls will reuse this data.
# Load validation data::   0%|          | 0/66 [00:00<?, ? examples/s]
# [Time: 00:01:38] - [PID: 4923] - [Model: bertmap]
# Data statistics:
#                      {
#     "num_training": 592,
#     "num_validation": 66
# }
# [Time: 00:00:49] - [PID: 4923] - [Model: bertmap]
# Data statistics:
#                      {
#     "num_training": 592,
#     "num_validation": 66
# }
# [Time: 00:00:26] - [PID: 4923] - [Model: bertmap]
# Data statistics:
#                      {
#     "num_training": 592,
#     "num_validation": 66
# }
# INFO:bertmap:Data statistics:
#                      {
#     "num_training": 592,
#     "num_validation": 66
# }
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='222' max='222' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [222/222 02:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.951100</td>
#       <td>0.420637</td>
#       <td>0.803030</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.366500</td>
#       <td>0.174227</td>
#       <td>0.969697</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.091700</td>
#       <td>0.146471</td>
#       <td>0.939394</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.010100</td>
#       <td>0.118343</td>
#       <td>0.969697</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.007100</td>
#       <td>0.124440</td>
#       <td>0.969697</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.002200</td>
#       <td>0.202089</td>
#       <td>0.954545</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.724500</td>
#       <td>0.115262</td>
#       <td>0.969697</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.002800</td>
#       <td>0.012407</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.001300</td>
#       <td>0.005811</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.001900</td>
#       <td>0.022883</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.010400</td>
#       <td>0.020723</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.001000</td>
#       <td>0.061033</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.001300</td>
#       <td>0.070034</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.002500</td>
#       <td>0.060136</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.002600</td>
#       <td>0.025876</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.002900</td>
#       <td>0.027085</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.000600</td>
#       <td>0.049549</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.001600</td>
#       <td>0.060268</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.000700</td>
#       <td>0.060732</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.661300</td>
#       <td>0.040091</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.001300</td>
#       <td>0.011729</td>
#       <td>0.984848</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.001400</td>
#       <td>0.008320</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# Fine-tuning finished, found best checkpoint at /content/bertmap/bert/checkpoint-90.
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# Fine-tuning finished, found best checkpoint at /content/bertmap/bert/checkpoint-90.
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# Fine-tuning finished, found best checkpoint at /content/bertmap/bert/checkpoint-90.
# INFO:bertmap:Fine-tuning finished, found best checkpoint at /content/bertmap/bert/checkpoint-90.
# The BERT model is set to eval mode for making predictions.
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4
# <style>
# .enlighten-bold {
#   font-weight: bold;
# }
# .enlighten-underline {
#   text-decoration: underline;
# }
# .enlighten-fg-bright-white {
#   color: #ffffff;
# }
# .enlighten-bg-lightslategray {
#   background-color: #778899;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre><span class="enlighten-bold enlighten-underline enlighten-fg-bright-white enlighten-bg-lightslategray">Global Matching                                Stage: Finished                                 00:15</span></pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Mapping Prediction 100%|████████████████████████████████| 49/49 [00:01&lt;00:00, 42.94 per src class/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Mapping Extension [Iteration #1] 6 mapping [00:00, 38.31 mapping/s]                                 </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Mapping Filtering 6 mapping [00:00, 41.55 mapping/s]                                                </pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Mapping Repairing 6 mapping [00:14, 0.42 mapping/s]                                                 </pre>
#   </div>
# </div>
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# Build inverted annotation index for candidate selection.
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# Build inverted annotation index for candidate selection.
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# Build inverted annotation index for candidate selection.
# INFO:bertmap:Build inverted annotation index for candidate selection.
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# Start global matching for each class in the source ontology.
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# Start global matching for each class in the source ontology.
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# Start global matching for each class in the source ontology.
# INFO:bertmap:Start global matching for each class in the source ontology.
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for http://www.w3.org/2002/07/owl#Thing are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for http://www.w3.org/2002/07/owl#Thing are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for http://www.w3.org/2002/07/owl#Thing are
# []
# INFO:bertmap:The best scored class mappings for http://www.w3.org/2002/07/owl#Thing are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# Save currently computed mappings to prevent undesirable loss.
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# Save currently computed mappings to prevent undesirable loss.
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# Save currently computed mappings to prevent undesirable loss.
# INFO:bertmap:Save currently computed mappings to prevent undesirable loss.
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Action are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Action are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Action are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Action are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Address are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Address are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Address are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Address are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/AddressComponent are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/AddressComponent are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/AddressComponent are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/AddressComponent are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Agent are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Agent <EquivalentTo> http://purl.org/dc/terms/Agent, 1.0)]
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Agent are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Agent <EquivalentTo> http://purl.org/dc/terms/Agent, 1.0)]
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Agent are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Agent <EquivalentTo> http://purl.org/dc/terms/Agent, 1.0)]
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Agent are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Agent <EquivalentTo> http://purl.org/dc/terms/Agent, 1.0)]
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/AgentRole are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/AgentRole <EquivalentTo> http://purl.org/dc/terms/Agent, 0.997266)]
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/AgentRole are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/AgentRole <EquivalentTo> http://purl.org/dc/terms/Agent, 0.997266)]
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/AgentRole are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/AgentRole <EquivalentTo> http://purl.org/dc/terms/Agent, 0.997266)]
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/AgentRole are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/AgentRole <EquivalentTo> http://purl.org/dc/terms/Agent, 0.997266)]
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Alias are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Alias are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Alias are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Alias are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.993476)]
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.993476)]
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.993476)]
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.993476)]
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/City are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/City are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/City are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/City are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Collection are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Collection are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Collection are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Collection are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionConcept are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionConcept are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionConcept are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionConcept are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionMembership are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CollectionMembership <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.997612)]
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionMembership are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CollectionMembership <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.997612)]
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionMembership are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CollectionMembership <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.997612)]
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/CollectionMembership are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/CollectionMembership <EquivalentTo> http://purl.org/ontology/mo/Membership, 0.997612)]
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Concept are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Concept are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Concept are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Concept are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Country are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Country are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Country are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Country are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Description are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Description are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Description are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Description are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/District are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/District are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/District are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/District are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Event are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Event are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Event are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Event are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Explanation are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Explanation are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Explanation are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Explanation are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/GeographicalFeature are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/GeographicalFeature are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/GeographicalFeature are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/GeographicalFeature are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationObject are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationObject are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationObject are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationObject are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationRealization are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationRealization are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationRealization are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/InformationRealization are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Language are
# []
# [Time: 00:03:47] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Language are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Language are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Language are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicDataset are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicDataset are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicDataset are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicDataset are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeDuration are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeDuration are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeDuration are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeDuration are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndex are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndex are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndex are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndex are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndexComponent are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndexComponent are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndexComponent are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeIndexComponent are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeInterval are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeInterval are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeInterval are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeInterval are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeValueType are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeValueType are
# []
# [Time: 00:03:24] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeValueType are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/MusicTimeValueType are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Name are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Name are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Name are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Name are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Organization are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Organization are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Organization are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Organization are
# []
# [Time: 00:04:36] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Person are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Person are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Person are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Person are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/PhysicalSite are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/PhysicalSite are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/PhysicalSite are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/PhysicalSite are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Place are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Place are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Place are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Place are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Province are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Province are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Province are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Province are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Reference are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Reference are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Reference are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Reference are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Region are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Region are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Region are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Region are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Role are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Role are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Role are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Role are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Situation are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Situation are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Situation are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Situation are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Source are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Source are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Source are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Source are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/SpatialObject are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/SpatialObject are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/SpatialObject are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/SpatialObject are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Street are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Street are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Street are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Street are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Task are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Task are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Task are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Task are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Theory are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Theory are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Theory are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Theory are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedName are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedName are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedName are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedName are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedRole are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedRole are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedRole are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedRole are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedSituation are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedSituation are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedSituation are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeIndexedSituation are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeInterval are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeInterval are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeInterval are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/TimeInterval are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Title are
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Title are
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Title are
# []
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Title are
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Type are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/dc/terms/MediaType, 0.993541), EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/ontology/mo/ReleaseType, 0.987826)]
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Type are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/dc/terms/MediaType, 0.993541), EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/ontology/mo/ReleaseType, 0.987826)]
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# The best scored class mappings for https://w3id.org/polifonia/ontology/core/Type are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/dc/terms/MediaType, 0.993541), EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/ontology/mo/ReleaseType, 0.987826)]
# INFO:bertmap:The best scored class mappings for https://w3id.org/polifonia/ontology/core/Type are
# [EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/dc/terms/MediaType, 0.993541), EntityMapping(https://w3id.org/polifonia/ontology/core/Type <EquivalentTo> http://purl.org/ontology/mo/ReleaseType, 0.987826)]
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Save currently computed mappings to prevent undesirable loss.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Save currently computed mappings to prevent undesirable loss.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Save currently computed mappings to prevent undesirable loss.
# INFO:bertmap:Save currently computed mappings to prevent undesirable loss.
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Finished mapping prediction for each class in the source ontology.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Finished mapping prediction for each class in the source ontology.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Finished mapping prediction for each class in the source ontology.
# INFO:bertmap:Finished mapping prediction for each class in the source ontology.
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Start mapping extension for each class pair with score >= 0.8.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Start mapping extension for each class pair with score >= 0.8.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Start mapping extension for each class pair with score >= 0.8.
# INFO:bertmap:Start mapping extension for each class pair with score >= 0.8.
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Agent', 'http://purl.org/dc/terms/Agent') are:
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Agent', 'http://purl.org/dc/terms/Agent') are:
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Agent', 'http://purl.org/dc/terms/Agent') are:
# []
# INFO:bertmap:New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Agent', 'http://purl.org/dc/terms/Agent') are:
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/AgentRole', 'http://purl.org/dc/terms/Agent') are:
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/AgentRole', 'http://purl.org/dc/terms/Agent') are:
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/AgentRole', 'http://purl.org/dc/terms/Agent') are:
# []
# INFO:bertmap:New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/AgentRole', 'http://purl.org/dc/terms/Agent') are:
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength', 'http://purl.org/ontology/mo/Membership') are:
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength', 'http://purl.org/ontology/mo/Membership') are:
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength', 'http://purl.org/ontology/mo/Membership') are:
# []
# INFO:bertmap:New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CellectionMembershipStrength', 'http://purl.org/ontology/mo/Membership') are:
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CollectionMembership', 'http://purl.org/ontology/mo/Membership') are:
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CollectionMembership', 'http://purl.org/ontology/mo/Membership') are:
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CollectionMembership', 'http://purl.org/ontology/mo/Membership') are:
# []
# INFO:bertmap:New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/CollectionMembership', 'http://purl.org/ontology/mo/Membership') are:
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/dc/terms/MediaType') are:
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/dc/terms/MediaType') are:
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/dc/terms/MediaType') are:
# []
# INFO:bertmap:New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/dc/terms/MediaType') are:
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/ontology/mo/ReleaseType') are:
# []
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/ontology/mo/ReleaseType') are:
# []
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/ontology/mo/ReleaseType') are:
# []
# INFO:bertmap:New mappings (in tuples) extended from ('https://w3id.org/polifonia/ontology/core/Type', 'http://purl.org/ontology/mo/ReleaseType') are:
# []
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Add 0 mappings at iteration #0.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Add 0 mappings at iteration #0.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Add 0 mappings at iteration #0.
# INFO:bertmap:Add 0 mappings at iteration #0.
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Finished iterative mapping extension with 0 new mappings and in total 6 extended mappings.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Finished iterative mapping extension with 0 new mappings and in total 6 extended mappings.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Finished iterative mapping extension with 0 new mappings and in total 6 extended mappings.
# INFO:bertmap:Finished iterative mapping extension with 0 new mappings and in total 6 extended mappings.
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Filtered the extended mappings by a threshold of 0.9.There are 6 mappings left for mapping repair.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Filtered the extended mappings by a threshold of 0.9.There are 6 mappings left for mapping repair.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Filtered the extended mappings by a threshold of 0.9.There are 6 mappings left for mapping repair.
# INFO:bertmap:Filtered the extended mappings by a threshold of 0.9.There are 6 mappings left for mapping repair.
# [Time: 00:04:37] - [PID: 4923] - [Model: bertmap]
# Repair the filtered mappings with LogMap debugger.
# [Time: 00:03:48] - [PID: 4923] - [Model: bertmap]
# Repair the filtered mappings with LogMap debugger.
# [Time: 00:03:25] - [PID: 4923] - [Model: bertmap]
# Repair the filtered mappings with LogMap debugger.
# INFO:bertmap:Repair the filtered mappings with LogMap debugger.
# Run the repair module of LogMap from /usr/local/lib/python3.10/dist-packages/deeponto/align/logmap.
# The jar command is:
# java -jar /usr/local/lib/python3.10/dist-packages/deeponto/align/logmap/logmap-matcher-4.0.jar DEBUGGER file:/content/core.owl file:/content/mo.owl TXT /content/bertmap/match/logmap-repair/filtered_mappings_for_LogMap_repair.txt /content/bertmap/match/logmap-repair false true.
# [Time: 00:04:51] - [PID: 4923] - [Model: bertmap]
# Mapping repair finished.
# [Time: 00:04:03] - [PID: 4923] - [Model: bertmap]
# Mapping repair finished.
# [Time: 00:03:39] - [PID: 4923] - [Model: bertmap]
# Mapping repair finished.
# INFO:bertmap:Mapping repair finished.

# %%
# !zip -r /content/bertmap-output.zip /content/bertmap/match
# Out:
# updating: content/bertmap/match/ (stored 0%)
# updating: content/bertmap/match/extended_mappings.tsv (deflated 66%)
# updating: content/bertmap/match/raw_mappings.tsv (deflated 66%)
# updating: content/bertmap/match/logmap-repair/ (stored 0%)
# updating: content/bertmap/match/logmap-repair/filtered_mappings_for_LogMap_repair.txt (deflated 67%)
# updating: content/bertmap/match/logmap-repair/mappings_repaired_with_LogMap.rdf (deflated 78%)
# updating: content/bertmap/match/logmap-repair/mappings_repaired_with_LogMap.tsv (deflated 72%)
# updating: content/bertmap/match/logmap-repair/mappings_repaired_with_LogMap.owl (deflated 93%)
# updating: content/bertmap/match/logmap-repair/mappings_repaired_with_LogMap.txt (deflated 72%)
# updating: content/bertmap/match/raw_mappings.json (deflated 86%)
# updating: content/bertmap/match/filtered_mappings.tsv (deflated 66%)
# updating: content/bertmap/match/repaired_mappings.tsv (deflated 71%)

# %%
# !rm -rf /content/bertmap
