# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Danysan1/unibo-ke-matching-ontologies/blob/main/wikidata/bertmap_match.ipynb)
# [![Open in Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/Danysan1/unibo-ke-matching-ontologies/blob/main/wikidata/bertmap_match.ipynb)
# [![Open in SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/Danysan1/unibo-ke-matching-ontologies/tree/main/wikidata/bertmap_match.ipynb)

# %% [markdown]
# # Polifonia - Wikidata alignment with BERTMap

# %%
# !pip3 uninstall torchdata wandb -y
# Out:
# WARNING: Ignoring invalid distribution -orch (/opt/conda/lib/python3.10/site-packages)
# WARNING: Skipping torchdata as it is not installed.
# WARNING: Ignoring invalid distribution -orch (/opt/conda/lib/python3.10/site-packages)
# WARNING: Skipping wandb as it is not installed.

# %%
# !pip3 install --upgrade datasets~=2.13.1 transformers[torch]~=4.30.2 torch~=2.0.1 torchvision~=0.15.2 torchaudio~=2.0.2 deeponto~=0.8.7
# Out:
# WARNING: Ignoring invalid distribution -orch (/opt/conda/lib/python3.10/site-packages)
# ...
#   Using cached torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
# ...
#   Using cached torchaudio-2.0.2-cp310-cp310-manylinux1_x86_64.whl (4.4 MB)
# ...
#   Using cached deeponto-0.8.7-py3-none-any.whl (89.7 MB)
# ...
# WARNING: Ignoring invalid distribution -orch (/opt/conda/lib/python3.10/site-packages)
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1
#     Uninstalling torchvision-0.15.1:
#       Successfully uninstalled torchvision-0.15.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.1
#     Uninstalling torchaudio-2.0.1:
#       Successfully uninstalled torchaudio-2.0.1
# ...

# %%
from deeponto.onto import Ontology
from deeponto.align.bertmap import BERTMapPipeline, DEFAULT_CONFIG_FILE
import shutil
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
! rm -rf /kaggle/working/bertmap/match /kaggle/working/matches /kaggle/working/all_matches.zip
! mkdir -p /kaggle/working/matches

# %%
def run_deeponto_matching(module:str):
    in_folder = "/kaggle/input"
    out_folder = "/kaggle/working"
    
    src_onto_file = f"{in_folder}/polifonia-music-representation/{module}"
    tgt_onto_file = f"{in_folder}/wikidata-music-ontology/music.owl"
    config_file = f"{in_folder}/polifonia-wikidata-bertmapyaml/bertmap.yaml"
    #config_file = DEFAULT_CONFIG_FILE
    
    config = BERTMapPipeline.load_bertmap_config(config_file)
    
    #BERTMapPipeline.save_bertmap_config(config, "bertmap.yaml")
    
    src_onto = Ontology(src_onto_file)
    tgt_onto = Ontology(tgt_onto_file)
    bertmap = BERTMapPipeline(src_onto, tgt_onto, config)
    
    shutil.move(f"{out_folder}/bertmap/match", f"{out_folder}/matches/{module}")
    
    #shutil.make_archive(f"{out_folder}/{module}", 'zip', f"{out_folder}/bertmap/match")
    #shutil.rmtree(f"{out_folder}/bertmap/match")

# %%
#run_deeponto_matching("ontology-network.ttl") # Only imports, counts as empty

# %%
#run_deeponto_matching("core.owl") # Outside the scope of the Wikidata exported ontology

# %%
run_deeponto_matching("algorithm-pattern.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P9899 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://www.rdaregistry.info/Elements/w/#P10238
# ...

# %%
run_deeponto_matching("bells.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against https://raw.githubusercontent.com/Danysan1/unibo-ke-matching-ontologies/main/polifonia/ontology/CLV.owl
# ...

# %%
run_deeponto_matching("cometa.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# ...

# %%
run_deeponto_matching("music-algorithm.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# ...

# %%
#run_deeponto_matching("music-analysis.owl") # Only imports, counts as empty

# %%
#run_deeponto_matching("music-annotation.ttl") # Only imports, counts as empty

# %%
run_deeponto_matching("jams.ttl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# ...

# %%
run_deeponto_matching("music-instrument.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# ...

# %%
run_deeponto_matching("music-meta.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P9899 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://www.rdaregistry.info/Elements/w/#P10238
# ...

# %%
run_deeponto_matching("music-projection.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# ...

# %%
run_deeponto_matching("music-representation.owl")
# Out:
# [main] INFO org.semanticweb.owlapi.io.AbstractOWLParser - URL connection input stream is compressed using gzip
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.AbstractState - Notice: root element does not have an xml:base. Relative IRIs will be resolved against file:/kaggle/input/wikidata-music-ontology/music.owl
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P658 -> http://www.w3.org/2002/07/owl#equivalentProperty -> https://schema.org/track
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P412 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://id.loc.gov/ontologies/bibframe/voice
# [main] INFO org.semanticweb.owlapi.rdf.rdfxml.parser.OWLRDFConsumer - Unparsed triple: http://www.wikidata.org/entity/P9899 -> http://www.w3.org/2002/07/owl#equivalentProperty -> http://www.rdaregistry.info/Elements/w/#P10238
# ...

# %%
! cat /kaggle/working/matches/*/repaired_mappings.tsv >> /kaggle/working/matches/all_repaired_mappings.tsv
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
shutil.make_archive(f"/kaggle/working/all_matches", 'zip', f"/kaggle/working/matches")
# Out:
# '/kaggle/working/all_matches.zip'
